# %% [markdown]
# # Data Wrangling:
# ### For Analysis such as: ANOVAS, MANOVAS, Correlation, Chi- Square, Random Forest, Regressions
# ### For Tableau

# %%
#Table of Content: 

#England and UK: 
## 1st Data Wrangle: Sepreated (total and type HazNonHaz) & Merged (Mergining Classificationa and Treatment Datasets)
## 2nd Data Wrangle: Updated (removing unwanted columns, and renaming columns)
## 3rd Data Wrangle: Reshaping

# %%
# Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.options.display.max_rows = None
pd.options.display.max_columns = None

pd.set_option('display.max_rows', 500)

from itertools import product

# %% [markdown]
# # 1st Data Wrangle

# %%
# devins starter code

# %% [markdown]
# ## Import Data

# %%
# Datasets were wrangled in R

# %%
# Updated_England_Industry
# Updated_England_Management
# Updated_Uk_Industry
# Updated_Uk_Management

# %% [markdown]
# # *England & UK*

# %%
# Total (without Haz/NonHaz Split) and Type (with Haz/NonHaz Split)

# %% [markdown]
# # Data Wrangle - Part 1

# %%
# iloc -> index location (calling only the first column - column 0)

# %%
england_industry_df = pd.read_csv("/Users/patelca/Desktop/WozU Data Science Program /WozU Final Project/Datasets/Data Wrangled Datasets/Updated_England_Industry.1.csv").iloc[:,1:]
england_managment_df = pd.read_csv("/Users/patelca/Desktop/WozU Data Science Program /WozU Final Project/Datasets/Data Wrangled Datasets/Updated_England_Management.1.csv").iloc[:,1:]

# %%
uk_industry_df = pd.read_csv("/Users/patelca/Desktop/WozU Data Science Program /WozU Final Project/Datasets/Data Wrangled Datasets/Updated_UK_Industry.1.csv").iloc[:,1:]
uk_managment_df = pd.read_csv("/Users/patelca/Desktop/WozU Data Science Program /WozU Final Project/Datasets/Data Wrangled Datasets/Updated_UK_Management.1.csv").iloc[:,1:]

# %%
# Calling the column names of the datasets
# Take a closer look at the columns of each dataset and see if anything is repeated, missing, or not neccessary

# %%
england_industry_df.columns
# Out:
# Index(['Year', 'EWC-STAT code', 'EWC-STAT description',
#        'Hazardous/Non-hazardous split', 'A', 'B', 'C10-C12', 'C13-C15', 'C16',
#        'C17_C18', 'C19', 'C20-C22', 'C23', 'C24_C25', 'C26-C30', 'C31-C33',
#        'D', 'E36_E37_E39', 'F', 'G-U_X_G4677', 'EP_HH',
#        'Total waste generation'],
#       dtype='object')

# %%
england_managment_df.columns
# Out:
# Index(['Year', 'EWC-STAT code', 'EWC-STAT description',
#        'Hazardous/Non-hazardous split', 'Energy recovery', 'Incineration',
#        'Recovery other than energy recovery - Except backfilling',
#        'Recovery other than energy recovery - Backfilling',
#        'Deposit onto or into land',
#        'Land treatment and release into water bodies', 'd`'],
#       dtype='object')

# %%
uk_industry_df.columns
# Out:
# Index(['Year', 'EWC-STAT code', 'EWC-STAT description',
#        'Hazardous/Non-hazardous split', 'A', 'B', 'C10-C12', 'C13-C15', 'C16',
#        'C17_C18', 'C19', 'C20-C22', 'C23', 'C24_C25', 'C26-C30', 'C31-C33',
#        'D', 'E36_E37_E39', 'F', 'G-U_X_G4677', 'EP_HH',
#        'Total waste generation'],
#       dtype='object')

# %%
uk_managment_df.columns
# Out:
# Index(['Year', 'EWC-STAT code', 'EWC-STAT description',
#        'Hazardous/Non-hazardous split', 'Energy recovery', 'Incineration',
#        'Recovery other than energy recovery - Except backfilling',
#        'Recovery other than energy recovery - Backfilling',
#        'Deposit onto or into land',
#        'Land treatment and release into water bodies',
#        'Total waste sent to final treatment'],
#       dtype='object')

# %% [markdown]
# # Data Wrangle -> Part 2

# %%
# in order to anaylize the data some things need to be changed... bc... for instance...
# loc -> location 
# calling the dataset.loc (in that df we only want where H/NH split == and != Total)

# %%
# Spliting Total and Haz/Non-Haz into two different dataframes of Industries Waste Gen

# %%
england_industry_total = england_industry_df.loc[england_industry_df['Hazardous/Non-hazardous split'] == "Total"]
england_industry_type = england_industry_df.loc[england_industry_df['Hazardous/Non-hazardous split'] != "Total"]

# %%
# Spliting Total and Haz/Non-Haz into two different dataframes of Industries Waste Gen

# %%
england_managment_total = england_managment_df.loc[england_managment_df['Hazardous/Non-hazardous split'] == "Total"]
england_managment_type = england_managment_df.loc[england_managment_df['Hazardous/Non-hazardous split'] != "Total"]

# %%
# Spliting Total and Haz/Non-Haz into two different dataframes of Industries Waste Gen

# %%
uk_industry_total = uk_industry_df.loc[uk_industry_df['Hazardous/Non-hazardous split'] == "Total"]
uk_industry_type = uk_industry_df.loc[uk_industry_df['Hazardous/Non-hazardous split'] != "Total"]

# %%
# Spliting Total and Haz/Non-Haz into two different dataframes of Industries Waste Gen

# %%
uk_managment_total = uk_managment_df.loc[uk_managment_df['Hazardous/Non-hazardous split'] == "Total"]
uk_managment_type = uk_managment_df.loc[uk_managment_df['Hazardous/Non-hazardous split'] != "Total"]

# %%
# double checking one of the above dataframe to see if the code above worked

# %%
england_managment_total
# Out:
#      Year     EWC-STAT code  \
# 2    2010              01.1
# 5    2010              01.2
# 8    2010              01.3
# 11   2010    01.4, 02, 03.1
# 14   2010              03.2
# 17   2010              03.3
# 20   2010                05
# 23   2010              06.1
# 26   2010              06.2
# 29   2010              06.3
# 32   2010              07.1
# 35   2010              07.2
# 38   2010              07.3
# 41   2010              07.4
# 44   2010              07.5
# 47   2010              07.6
# 50   2010              07.7
# 53   2010               08*
# 56   2010              08.1
# 59   2010             08.41
# 62   2010              09.1
# 65   2010              09.2
# 68   2010              09.3
# 71   2010              10.1
# 74   2010              10.2
# 77   2010              10.3
# 80   2010                11
# 83   2010              12.1
# 86   2010  12.2, 12.3, 12.5
# 89   2010              12.4
# 92   2010              12.6
# 95   2010              12.7
# ...

# %%
# Combining two subject indentifier -> Year and EWC-STAT description -> which will make each row unique

# - They did not match on the rows that were aggregates "Total waste generated" and "Total waste managed"

# - So we removed those because they were rows that represented total's

# Line 2: double checking to see what are false

# %%
combine_yr_ewc = england_industry_total[['Year', 'EWC-STAT description']] == england_managment_total[['Year', 'EWC-STAT description']]
combine_yr_ewc
# Out:
#      Year  EWC-STAT description
# 2    True                  True
# 5    True                  True
# 8    True                  True
# 11   True                  True
# 14   True                  True
# 17   True                  True
# 20   True                  True
# 23   True                  True
# 26   True                  True
# 29   True                  True
# 32   True                  True
# 35   True                  True
# 38   True                  True
# 41   True                  True
# 44   True                  True
# 47   True                  True
# 50   True                  True
# 53   True                  True
# 56   True                  True
# 59   True                  True
# 62   True                  True
# 65   True                  True
# 68   True                  True
# 71   True                  True
# 74   True                  True
# 77   True                  True
# 80   True                  True
# 83   True                  True
# ...

# %%
combine_yr_ewc2 = england_industry_type[['Year', 'EWC-STAT description']] == england_managment_type[['Year', 'EWC-STAT description']]
combine_yr_ewc2
# Out:
#      Year  EWC-STAT description
# 0    True                  True
# 1    True                  True
# 3    True                  True
# 4    True                  True
# 6    True                  True
# 7    True                  True
# 9    True                  True
# 10   True                  True
# 12   True                  True
# 13   True                  True
# 15   True                  True
# 16   True                  True
# 18   True                  True
# 19   True                  True
# 21   True                  True
# 22   True                  True
# 24   True                  True
# 25   True                  True
# 27   True                  True
# 28   True                  True
# 30   True                  True
# 31   True                  True
# 33   True                  True
# 34   True                  True
# 36   True                  True
# 37   True                  True
# 39   True                  True
# 40   True                  True
# ...

# %%
combine_yr_ewc3 = uk_industry_total[['Year', 'EWC-STAT description']] == uk_managment_total[['Year', 'EWC-STAT description']]
combine_yr_ewc3
# Out:
#      Year  EWC-STAT description
# 2    True                  True
# 5    True                  True
# 8    True                  True
# 11   True                  True
# 14   True                  True
# 17   True                  True
# 20   True                  True
# 23   True                  True
# 26   True                  True
# 29   True                  True
# 32   True                  True
# 35   True                  True
# 38   True                  True
# 41   True                  True
# 44   True                  True
# 47   True                  True
# 50   True                  True
# 53   True                  True
# 56   True                  True
# 59   True                  True
# 62   True                  True
# 65   True                  True
# 68   True                  True
# 71   True                  True
# 74   True                  True
# 77   True                  True
# 80   True                  True
# 83   True                  True
# ...

# %%
combine_yr_ewc4 = uk_industry_type[['Year', 'EWC-STAT description']] == uk_managment_type[['Year', 'EWC-STAT description']]
combine_yr_ewc4
# Out:
#      Year  EWC-STAT description
# 0    True                  True
# 1    True                  True
# 3    True                  True
# 4    True                  True
# 6    True                  True
# 7    True                  True
# 9    True                  True
# 10   True                  True
# 12   True                  True
# 13   True                  True
# 15   True                  True
# 16   True                  True
# 18   True                  True
# 19   True                  True
# 21   True                  True
# 22   True                  True
# 24   True                  True
# 25   True                  True
# 27   True                  True
# 28   True                  True
# 30   True                  True
# 31   True                  True
# 33   True                  True
# 34   True                  True
# 36   True                  True
# 37   True                  True
# 39   True                  True
# 40   True                  True
# ...

# %% [markdown]
# ## Results ENG:
# - the years match but the EWC-STAT do not (101, 203, 305, 407)
# - calling all the False (i.e. all the total waste from different years- ) from the column EWC to see aren't the same, so we can remove before we concatinate meaning combine two worksheets.
# - if == True: it would return all rows where they DO match, which would be all except 101, 203, 305, 407
# - if == False: it would return all rows where they DO NOT match, which would be 101, 203, 305, 407

# %%
# loc-> locating

# %%
combine_yr_ewc.loc[combine_yr_ewc['EWC-STAT description'] == False]
# Out:
#      Year  EWC-STAT description
# 101  True                 False
# 203  True                 False
# 305  True                 False
# 407  True                 False

# %%
combine_yr_ewc2.loc[combine_yr_ewc2['EWC-STAT description'] == False]
# Out:
#      Year  EWC-STAT description
# 99   True                 False
# 100  True                 False
# 201  True                 False
# 202  True                 False
# 303  True                 False
# 304  True                 False
# 405  True                 False
# 406  True                 False

# %%
combine_yr_ewc3.loc[combine_yr_ewc3['EWC-STAT description'] == False]
# Out:
#      Year  EWC-STAT description
# 101  True                 False
# 203  True                 False
# 305  True                 False
# 407  True                 False

# %%
combine_yr_ewc4.loc[combine_yr_ewc4['EWC-STAT description'] == False]
# Out:
#      Year  EWC-STAT description
# 99   True                 False
# 100  True                 False
# 201  True                 False
# 202  True                 False
# 303  True                 False
# 304  True                 False
# 405  True                 False
# 406  True                 False

# %%
# Printing the length before we remove 'Total waste generation'

# %%
print(len(england_industry_total))
len(england_managment_total)
# Out:
# 136
# 136

# %%
print(len(england_managment_type))
len(england_industry_type)
# Out:
# 272
# 272

# %%
print(len(uk_industry_total))
len(uk_managment_total)
# Out:
# 136
# 136

# %%
print(len(uk_industry_type))
len(uk_managment_type)
# Out:
# 272
# 272

# %%
# Row Manipulation: Calling all the rows to remove the rows that have 'Total waste generation'
# Double Checking to make sure: Printing the length after remove 'Total waste generation'

# Row Manipulation: Calling all the rows to remove the rows that have 'Total waste treated'
# Double Checking to make sure: Printing the length after remove 'Total waste treated'

# %%
england_industry_total = england_industry_total.loc[england_industry_total['EWC-STAT description'] != '*Total waste generation',:]
len(england_industry_total)
# Out:
# 132

# %%
england_managment_total = england_managment_total.loc[england_managment_total['EWC-STAT description'] != '*Total waste treated',:]
len(england_managment_total)
# Out:
# 132

# %%
england_industry_type = england_industry_type.loc[england_industry_type['EWC-STAT description'] != '*Total waste generation',:]
len(england_industry_type)
# Out:
# 264

# %%
england_managment_type = england_managment_type.loc[england_managment_type['EWC-STAT description'] != '*Total waste treated',:]
len(england_managment_type)
# Out:
# 264

# %%
uk_industry_total = uk_industry_total.loc[uk_industry_total['EWC-STAT description'] != '*Total waste generation',:]
len(uk_industry_total)
# Out:
# 132

# %%
uk_managment_total = uk_managment_total.loc[uk_managment_total['EWC-STAT description'] != '*Total waste treated',:]
len(uk_managment_total)
# Out:
# 132

# %%
uk_industry_type = uk_industry_type.loc[uk_industry_type['EWC-STAT description'] != '*Total waste generation',:]
len(uk_industry_type)
# Out:
# 264

# %%
uk_managment_type = uk_managment_type.loc[uk_managment_type['EWC-STAT description'] != '*Total waste treated',:]
len(uk_managment_type)
# Out:
# 264

# %%
#### Merge Worksheets

# Above lines, we made sure Year and EWC Swat were exact same before we concatenated datasets
# Now that both tables are set to True Bouleans -> meaning removed total waste gen and treated; can combine both worksheets now that the unique subject identifier are both aligned

# %%
total_full = pd.concat([england_industry_total, england_managment_total], axis=1)

# %%
type_full = pd.concat([england_industry_type, england_managment_type], axis=1)

# %%
total_full_uk = pd.concat([uk_industry_total, uk_managment_total], axis=1)

# %%
type_full_uk = pd.concat([uk_industry_type, uk_managment_type], axis=1)

# %%
# Printing the length after we have mereged the datasets

# %%
len(total_full)
# Out:
# 132

# %%
len(type_full)
# Out:
# 264

# %%
len(total_full_uk)
# Out:
# 132

# %%
len(type_full_uk)
# Out:
# 264

# %%
# Calling the column names of the concated dataset
# Checking if both mereged corectly and have all the columns; either by .columns or .head()

# %%
total_full.columns
# Out:
# Index(['Year', 'EWC-STAT code', 'EWC-STAT description',
#        'Hazardous/Non-hazardous split', 'A', 'B', 'C10-C12', 'C13-C15', 'C16',
#        'C17_C18', 'C19', 'C20-C22', 'C23', 'C24_C25', 'C26-C30', 'C31-C33',
#        'D', 'E36_E37_E39', 'F', 'G-U_X_G4677', 'EP_HH',
#        'Total waste generation', 'Year', 'EWC-STAT code',
#        'EWC-STAT description', 'Hazardous/Non-hazardous split',
#        'Energy recovery', 'Incineration',
#        'Recovery other than energy recovery - Except backfilling',
#        'Recovery other than energy recovery - Backfilling',
#        'Deposit onto or into land',
#        'Land treatment and release into water bodies', 'd`'],
#       dtype='object')

# %%
type_full.columns
# Out:
# Index(['Year', 'EWC-STAT code', 'EWC-STAT description',
#        'Hazardous/Non-hazardous split', 'A', 'B', 'C10-C12', 'C13-C15', 'C16',
#        'C17_C18', 'C19', 'C20-C22', 'C23', 'C24_C25', 'C26-C30', 'C31-C33',
#        'D', 'E36_E37_E39', 'F', 'G-U_X_G4677', 'EP_HH',
#        'Total waste generation', 'Year', 'EWC-STAT code',
#        'EWC-STAT description', 'Hazardous/Non-hazardous split',
#        'Energy recovery', 'Incineration',
#        'Recovery other than energy recovery - Except backfilling',
#        'Recovery other than energy recovery - Backfilling',
#        'Deposit onto or into land',
#        'Land treatment and release into water bodies', 'd`'],
#       dtype='object')

# %%
total_full_uk.columns
# Out:
# Index(['Year', 'EWC-STAT code', 'EWC-STAT description',
#        'Hazardous/Non-hazardous split', 'A', 'B', 'C10-C12', 'C13-C15', 'C16',
#        'C17_C18', 'C19', 'C20-C22', 'C23', 'C24_C25', 'C26-C30', 'C31-C33',
#        'D', 'E36_E37_E39', 'F', 'G-U_X_G4677', 'EP_HH',
#        'Total waste generation', 'Year', 'EWC-STAT code',
#        'EWC-STAT description', 'Hazardous/Non-hazardous split',
#        'Energy recovery', 'Incineration',
#        'Recovery other than energy recovery - Except backfilling',
#        'Recovery other than energy recovery - Backfilling',
#        'Deposit onto or into land',
#        'Land treatment and release into water bodies',
#        'Total waste sent to final treatment'],
#       dtype='object')

# %%
type_full_uk.head()
# Out:
#    Year EWC-STAT code             EWC-STAT description  \
# 0  2010          01.1                   Spent solvents
# 1  2010          01.1                   Spent solvents
# 3  2010          01.2  Acid, alkaline or saline wastes
# 4  2010          01.2  Acid, alkaline or saline wastes
# 6  2010          01.3                        Used oils
#
#   Hazardous/Non-hazardous split                   A     B             C10-C12  \
# 0                     Hazardous                   0     0  84.949460377175086
# 1                 Non-hazardous                   z     z                   z
# 3                     Hazardous                   0     0  2644.4743226227511
# 4                 Non-hazardous                   0     0  3317.5710114636677
# 6                     Hazardous  31991.637710338411  8117  6775.0993747785724
#
#               C13-C15                 C16             C17_C18  \
# 0  25.203928515981719  45.058659743050029  2825.0664151318888
# ...

# %%
# Exporting the file as csv

# %%
total_full.to_csv('England_Total_Full.csv')
type_full.to_csv('England_Type_Full.csv')
total_full_uk.to_csv('UK_Total_Full.csv')
type_full_uk.to_csv('UK_Type_Full.csv')

# %% [markdown]
# ________

# %% [markdown]
# # 2nd Data Wrangle

# %% [markdown]
# # *UK & England*

# %% [markdown]
# ## Load Type Data without a 'z'
#
# - Making a list of missing value types
#
# - Dropping "z"s from type without futher wrangle

# %%
missing_values = ["z"]
uk_type = pd.read_csv("/Users/patelca/Desktop/WozU Data Science Program /WozU Final Project/Datasets/Data Wrangled Datasets/UK_Type_Full.csv", na_values = missing_values)

# %%
uk_type.head()
# Out:
#    Unnamed: 0  Year EWC-STAT code             EWC-STAT description  \
# 0           0  2010          01.1                   Spent solvents
# 1           1  2010          01.1                   Spent solvents
# 2           3  2010          01.2  Acid, alkaline or saline wastes
# 3           4  2010          01.2  Acid, alkaline or saline wastes
# 4           6  2010          01.3                        Used oils
#
#   Hazardous/Non-hazardous split            A       B      C10-C12    C13-C15  \
# 0                     Hazardous      0.00000     0.0    84.949460  25.203929
# 1                 Non-hazardous          NaN     NaN          NaN        NaN
# 2                     Hazardous      0.00000     0.0  2644.474323   1.589267
# 3                 Non-hazardous      0.00000     0.0  3317.571011   1.725589
# 4                     Hazardous  31991.63771  8117.0  6775.099375  61.164693
#
#           C16      C17_C18          C19       C20-C22           C23  \
# ...

# %%
uk_type.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'EWC-STAT code', 'EWC-STAT description',
#        'Hazardous/Non-hazardous split', 'A', 'B', 'C10-C12', 'C13-C15', 'C16',
#        'C17_C18', 'C19', 'C20-C22', 'C23', 'C24_C25', 'C26-C30', 'C31-C33',
#        'D', 'E36_E37_E39', 'F', 'G-U_X_G4677', 'EP_HH',
#        'Total waste generation', 'Year.1', 'EWC-STAT code.1',
#        'EWC-STAT description.1', 'Hazardous/Non-hazardous split.1',
#        'Energy recovery', 'Incineration',
#        'Recovery other than energy recovery - Except backfilling',
#        'Recovery other than energy recovery - Backfilling',
#        'Deposit onto or into land',
#        'Land treatment and release into water bodies',
#        'Total waste sent to final treatment'],
#       dtype='object')

# %%
uk_total = pd.read_csv("/Users/patelca/Desktop/WozU Data Science Program /WozU Final Project/Datasets/Data Wrangled Datasets/UK_Total_Full.csv")

# %%
missing_values = ["z"]
eng_type = pd.read_csv("/Users/patelca/Desktop/WozU Data Science Program /WozU Final Project/Datasets/Data Wrangled Datasets/England_Type_Full.csv", na_values = missing_values)

# %%
eng_total = pd.read_csv("/Users/patelca/Desktop/WozU Data Science Program /WozU Final Project/Datasets/Data Wrangled Datasets/England_Total_Full.csv")

# %%
eng_total.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'EWC-STAT code', 'EWC-STAT description',
#        'Hazardous/Non-hazardous split', 'A', 'B', 'C10-C12', 'C13-C15', 'C16',
#        'C17_C18', 'C19', 'C20-C22', 'C23', 'C24_C25', 'C26-C30', 'C31-C33',
#        'D', 'E36_E37_E39', 'F', 'G-U_X_G4677', 'EP_HH',
#        'Total waste generation', 'Year.1', 'EWC-STAT code.1',
#        'EWC-STAT description.1', 'Hazardous/Non-hazardous split.1',
#        'Energy recovery', 'Incineration',
#        'Recovery other than energy recovery - Except backfilling',
#        'Recovery other than energy recovery - Backfilling',
#        'Deposit onto or into land',
#        'Land treatment and release into water bodies', 'd`'],
#       dtype='object')

# %% [markdown]
# #### Drop repeated/unwanted columns

# %%
uk_type1 = uk_type.drop(['Unnamed: 0', 'EWC-STAT code', 'Year.1', 'EWC-STAT code.1', 'EWC-STAT description.1', 'Hazardous/Non-hazardous split.1'], axis=1)

# %%
uk_type1.head(1)
# Out:
#    Year EWC-STAT description Hazardous/Non-hazardous split    A    B  \
# 0  2010       Spent solvents                     Hazardous  0.0  0.0
#
#     C10-C12    C13-C15       C16      C17_C18        C19       C20-C22  \
# 0  84.94946  25.203929  45.05866  2825.066415  44.387391  95629.608909
#
#           C23     C24_C25      C26-C30     C31-C33          D  E36_E37_E39  \
# 0  100.802691  819.016386  1917.640137  774.244521  21.471971     1.451289
#
#      F   G-U_X_G4677  EP_HH  Total waste generation  Energy recovery  \
# 0  0.0  14969.237745    0.0           117258.139503           8581.0
#
#    Incineration  Recovery other than energy recovery - Except backfilling  \
# 0           0.0                                           8436.487
#
#    Recovery other than energy recovery - Backfilling  \
# 0                                                0.0
#
#    Deposit onto or into land  Land treatment and release into water bodies  \
# ...

# %%
uk_total1 = uk_total.drop(['Unnamed: 0', 'EWC-STAT code', 'Year.1', 'EWC-STAT code.1', 'EWC-STAT description.1', 'Hazardous/Non-hazardous split.1'], axis=1)

# %%
uk_total1.head(1)
# Out:
#    Year EWC-STAT description Hazardous/Non-hazardous split    A    B  \
# 0  2010       Spent solvents                         Total  0.0  0.0
#
#     C10-C12    C13-C15       C16      C17_C18        C19       C20-C22  \
# 0  84.94946  25.203929  45.05866  2825.066415  44.387391  95629.608909
#
#           C23     C24_C25      C26-C30     C31-C33          D  E36_E37_E39  \
# 0  100.802691  819.016386  1917.640137  774.244521  21.471971     1.451289
#
#      F   G-U_X_G4677  EP_HH  Total waste generation  Energy recovery  \
# 0  0.0  14969.237745    0.0           117258.139503           8581.0
#
#    Incineration  Recovery other than energy recovery - Except backfilling  \
# 0           0.0                                           8436.487
#
#    Recovery other than energy recovery - Backfilling  \
# 0                                                0.0
#
#    Deposit onto or into land  Land treatment and release into water bodies  \
# ...

# %%
eng_type1 = eng_type.drop(['Unnamed: 0', 'EWC-STAT code', 'Year.1', 'EWC-STAT code.1', 'EWC-STAT description.1', 'Hazardous/Non-hazardous split.1'], axis=1)

# %%
eng_type1.head(1)
# Out:
#    Year EWC-STAT description Hazardous/Non-hazardous split    A    B  \
# 0  2010       Spent solvents                     Hazardous  0.0  0.0
#
#      C10-C12   C13-C15        C16     C17_C18        C19       C20-C22  \
# 0  13.697857  9.133929  16.319214  693.591932  18.387391  39262.057248
#
#         C23     C24_C25     C26-C30   C31-C33         D  E36_E37_E39    F  \
# 0  9.554549  338.426256  355.766317  82.01455  2.012466     0.451289  0.0
#
#    G-U_X_G4677  EP_HH  Total waste generation  Energy recovery  Incineration  \
# 0  1046.579003    0.0               41847.992              0.0           0.0
#
#    Recovery other than energy recovery - Except backfilling  \
# 0                                           8436.487
#
#    Recovery other than energy recovery - Backfilling  \
# 0                                                0.0
#
#    Deposit onto or into land  Land treatment and release into water bodies  \
# ...

# %%
eng_total1 = eng_total.drop(['Unnamed: 0', 'EWC-STAT code', 'Year.1', 'EWC-STAT code.1', 'EWC-STAT description.1', 'Hazardous/Non-hazardous split.1'], axis=1)

# %%
eng_total1.head(1)
# Out:
#    Year EWC-STAT description Hazardous/Non-hazardous split    A    B  \
# 0  2010       Spent solvents                         Total  0.0  0.0
#
#      C10-C12   C13-C15        C16     C17_C18        C19       C20-C22  \
# 0  13.697857  9.133929  16.319214  693.591932  18.387391  39262.057248
#
#         C23     C24_C25     C26-C30   C31-C33         D  E36_E37_E39    F  \
# 0  9.554549  338.426256  355.766317  82.01455  2.012466     0.451289  0.0
#
#    G-U_X_G4677  EP_HH  Total waste generation  Energy recovery  Incineration  \
# 0  1046.579003    0.0               41847.992              0.0           0.0
#
#    Recovery other than energy recovery - Except backfilling  \
# 0                                           8436.487
#
#    Recovery other than energy recovery - Backfilling  \
# 0                                                0.0
#
#    Deposit onto or into land  Land treatment and release into water bodies  \
# ...

# %% [markdown]
# #### Renaming the columns

# %%
uk_type1.rename(columns={'EWC-STAT description' : 'Waste_types', 'Hazardous/Non-hazardous split' : 'Haz_NonHaz', 'C10-C12' : 'C10_C12', 'C13-C15' : 'C13_C15', 'C20-C22' : 'C20_C22', 'C26-C30' : 'C26_C30', 'C31-C33' : 'C31_C33', 'G-U_X_G4677': 'G_U_X_G4677', 'Total waste generation' : 'Total_waste_gen', 'Energy recovery' : 'Energy_recovery', 'Recovery other than energy recovery - Except backfilling' : 'No_backfilling', 'Recovery other than energy recovery - Backfilling' : 'Backfilling', 'Deposit onto or into land' : 'Deposit_land', 'Land treatment and release into water bodies' : 'Treated_waterbodies', 'Total waste sent to final treatment' : 'Total_treatment'}, inplace=True)

# %%
uk_total1.rename(columns={'EWC-STAT description' : 'Waste_types', 'Hazardous/Non-hazardous split' : 'Haz_NonHaz', 'C10-C12' : 'C10_C12', 'C13-C15' : 'C13_C15', 'C20-C22' : 'C20_C22', 'C26-C30' : 'C26_C30', 'C31-C33' : 'C31_C33', 'G-U_X_G4677': 'G_U_X_G4677', 'Total waste generation' : 'Total_waste_gen', 'Energy recovery' : 'Energy_recovery', 'Recovery other than energy recovery - Except backfilling' : 'No_backfilling', 'Recovery other than energy recovery - Backfilling' : 'Backfilling', 'Deposit onto or into land' : 'Deposit_land', 'Land treatment and release into water bodies' : 'Treated_waterbodies', 'Total waste sent to final treatment' : 'Total_treatment'}, inplace=True)

# %%
uk_total1.columns
# Out:
# Index(['Year', 'Waste_types', 'Haz_NonHaz', 'A', 'B', 'C10_C12', 'C13_C15',
#        'C16', 'C17_C18', 'C19', 'C20_C22', 'C23', 'C24_C25', 'C26_C30',
#        'C31_C33', 'D', 'E36_E37_E39', 'F', 'G_U_X_G4677', 'EP_HH',
#        'Total_waste_gen', 'Energy_recovery', 'Incineration', 'No_backfilling',
#        'Backfilling', 'Deposit_land', 'Treated_waterbodies',
#        'Total_treatment'],
#       dtype='object')

# %%
eng_type1.rename(columns={'EWC-STAT description' : 'Waste_types', 'Hazardous/Non-hazardous split' : 'Haz_NonHaz', 'C10-C12' : 'C10_C12', 'C13-C15' : 'C13_C15', 'C20-C22' : 'C20_C22', 'C26-C30' : 'C26_C30', 'C31-C33' : 'C31_C33', 'G-U_X_G4677': 'G_U_X_G4677', 'Total waste generation' : 'Total_waste_gen', 'Energy recovery' : 'Energy_recovery', 'Recovery other than energy recovery - Except backfilling' : 'No_backfilling', 'Recovery other than energy recovery - Backfilling' : 'Backfilling', 'Deposit onto or into land' : 'Deposit_land', 'Land treatment and release into water bodies' : 'Treated_waterbodies', 'Total waste sent to final treatment' : 'Total_treatment'}, inplace=True)

# %%
eng_total1.rename(columns={'EWC-STAT description' : 'Waste_types', 'Hazardous/Non-hazardous split' : 'Haz_NonHaz', 'C10-C12' : 'C10_C12', 'C13-C15' : 'C13_C15', 'C20-C22' : 'C20_C22', 'C26-C30' : 'C26_C30', 'C31-C33' : 'C31_C33', 'G-U_X_G4677': 'G_U_X_G4677', 'Total waste generation' : 'Total_waste_gen', 'Energy recovery' : 'Energy_recovery', 'Recovery other than energy recovery - Except backfilling' : 'No_backfilling', 'Recovery other than energy recovery - Backfilling' : 'Backfilling', 'Deposit onto or into land' : 'Deposit_land', 'Land treatment and release into water bodies' : 'Treated_waterbodies', 'd`' : 'Total_treatment'}, inplace=True)

# %%
eng_total1.columns
# Out:
# Index(['Year', 'Waste_types', 'Haz_NonHaz', 'A', 'B', 'C10_C12', 'C13_C15',
#        'C16', 'C17_C18', 'C19', 'C20_C22', 'C23', 'C24_C25', 'C26_C30',
#        'C31_C33', 'D', 'E36_E37_E39', 'F', 'G_U_X_G4677', 'EP_HH',
#        'Total_waste_gen', 'Energy_recovery', 'Incineration', 'No_backfilling',
#        'Backfilling', 'Deposit_land', 'Treated_waterbodies',
#        'Total_treatment'],
#       dtype='object')

# %% [markdown]
# #### Export Datasets as csv

# %%
uk_total1.to_csv('UK_Total_updated.csv')
uk_type1.to_csv('UK_Type_updated.csv')
eng_total1.to_csv('Eng_Total_updated.csv')
eng_type1.to_csv('Eng_Type_updated.csv')

# %% [markdown]
# _____

# %% [markdown]
# # 3rd Data Wrangle

# %% [markdown]
# ### Data Wrangling for all ANOVAs -> Reshaping the data by using melt function
#
# Devin's: reshaped_location = pd.melt(total_full.drop("EWC-STAT code", axis=1), id_vars=['Year','EWC-STAT description'], value_vars=total_full.iloc[:,3:20].columns,var_name = "Location_Type", value_name="Weight")
#
# Meredith's: MeltedUKTotal1 = pd.melt(UK_Total_updated, id_vars = ['Year', 'Waste_types'], value_vars = ['A', 'B', 'C10_C12', 'C16'])
#
# - This is to be able to find the ANOVAs of the different A,  B, C (classifications) columns. You will need to add all your other columns in

# %% [markdown]
# ##### England:

# %%
# Reshaping England Location(classification) by using melt() function

# %%
reshaped_location_eng = pd.melt(eng_total1, id_vars=['Year','Waste_types'], value_vars=eng_total1.iloc[:,3:20].columns, var_name = "Location_Type", value_name="Weight")

# %%
# Export file as csv

# %%
reshaped_location_eng.to_csv("Reshaped_Location.csv", index=False)

# %%
# Reshaping England Treatment methods by using melt() function

# %%
reshaped_treatment_eng = pd.melt(eng_total1, id_vars=['Year','Waste_types'], value_vars=eng_total1.iloc[:,21:-1].columns,
       var_name = "Treatment_Type", value_name="Weight")

# %%
# Export file as csv

# %%
reshaped_treatment_eng.to_csv("Reshaped_Treatment.csv", index=False)

# %%
# Grouping groupby() of waste and treatment by aggregate sum() function

# %%
total_waste_and_treatment_by_type_eng = eng_total1[["Waste_types", "Total_waste_gen", 
                                       "Total_treatment"]].groupby("Waste_types").sum().reset_index()

# %%
# Export file as csv

# %%
total_waste_and_treatment_by_type_eng.to_csv("total_waste_and_treatment_by_type_Eng.csv", index=False)

# %% [markdown]
# ##### UK:

# %%
# Reshaping UK Location (classifications) by using melt() function

# %%
reshaped_location_uk = pd.melt(uk_total1, id_vars=['Year', 'Waste_types'], value_vars=uk_total1.iloc[:,3:20].columns, var_name = "Location_Type", value_name="Weight")

# %%
# Export file as csv

# %%
reshaped_location_uk.to_csv("UK_Reshaped_Location.csv", index=False)

# %%
# Reshaping UK Treatment methods by using melt() function

# %%
reshaped_treatment_uk = pd.melt(uk_total1, id_vars=['Year', 'Waste_types'], value_vars=uk_total1.iloc[:,21:-1].columns,
        var_name = "Location_Type", value_name="Weight")

# %%
# Export file as csv

# %%
reshaped_treatment_uk.to_csv("UK_Reshaped_Treatment.csv", index=False)

# %%
# Grouping groupby() of waste and treatment by aggregate sum() function

# %%
total_waste_and_treatment_by_type_eng = uk_total1[["Waste_types", "Total_waste_gen", 
                                       "Total_treatment"]].groupby("Waste_types").sum().reset_index()

# %%
# Export file as csv

# %%
total_waste_and_treatment_by_type_eng.to_csv("total_waste_and_treatment_by_type_UK.csv", index=False)

# %% [markdown]
# ##### Combining 2 countires & Reshaping -> UK&England

# %%
uk_total1.columns
# Out:
# Index(['Year', 'Waste_types', 'Haz_NonHaz', 'A', 'B', 'C10_C12', 'C13_C15',
#        'C16', 'C17_C18', 'C19', 'C20_C22', 'C23', 'C24_C25', 'C26_C30',
#        'C31_C33', 'D', 'E36_E37_E39', 'F', 'G_U_X_G4677', 'EP_HH',
#        'Total_waste_gen', 'Energy_recovery', 'Incineration', 'No_backfilling',
#        'Backfilling', 'Deposit_land', 'Treated_waterbodies',
#        'Total_treatment'],
#       dtype='object')

# %%
eng_total11 = eng_total1.drop(['Total_waste_gen', 'Total_treatment'], axis=1)

# %%
uk_total11 = uk_total1.drop(['Year', 'Waste_types', 'Haz_NonHaz', 'Total_waste_gen', 'Total_treatment'], axis=1)

# %%
# Merging both countires eng and uk datasets

# %%
countries = pd.concat([eng_total11, uk_total11], axis=1)

# %%
countries.columns
# Out:
# Index(['Year', 'Waste_types', 'Haz_NonHaz', 'A', 'B', 'C10_C12', 'C13_C15',
#        'C16', 'C17_C18', 'C19', 'C20_C22', 'C23', 'C24_C25', 'C26_C30',
#        'C31_C33', 'D', 'E36_E37_E39', 'F', 'G_U_X_G4677', 'EP_HH',
#        'Energy_recovery', 'Incineration', 'No_backfilling', 'Backfilling',
#        'Deposit_land', 'Treated_waterbodies', 'A', 'B', 'C10_C12', 'C13_C15',
#        'C16', 'C17_C18', 'C19', 'C20_C22', 'C23', 'C24_C25', 'C26_C30',
#        'C31_C33', 'D', 'E36_E37_E39', 'F', 'G_U_X_G4677', 'EP_HH',
#        'Energy_recovery', 'Incineration', 'No_backfilling', 'Backfilling',
#        'Deposit_land', 'Treated_waterbodies'],
#       dtype='object')

# %%
# Reshaping by using melt() function

# %%
reshaped_Countries = pd.melt(countries.drop('Haz_NonHaz', axis=1), id_vars=['Year','Waste_types'], value_vars=countries.iloc[:,3:-1].columns,
       var_name = "Location&Treatment_Type", value_name="Weight")

# %%
# Export file as csv

# %%
reshaped_Countries.to_csv("Reshaped_Countries.csv", index=False)
