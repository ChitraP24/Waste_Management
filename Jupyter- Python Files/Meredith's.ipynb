# %%
import pandas as pd
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
UK_Total_updated = pd.read_csv("UK_Total_updated.csv")
UK_Total_updated.head()
# Out:
#    Unnamed: 0  Year                      Waste_types Haz_NonHaz  \
# 0           0  2010                   Spent solvents      Total
# 1           1  2010  Acid, alkaline or saline wastes      Total
# 2           2  2010                        Used oils      Total
# 3           3  2010                  Chemical wastes      Total
# 4           4  2010      Industrial effluent sludges      Total
#
#                A        B       C10_C12      C13_C15         C16  \
# 0       0.000000     0.00     13.697857     9.133929   16.319214
# 1       0.000000     0.00   5387.579199     3.314856   28.716047
# 2   21570.796028  1442.00   3709.416719    47.053809   53.668114
# 3  103009.387438   748.00    552.750023  2833.086749  467.704496
# 4       0.000000  1653.48  49775.954048  1883.063196   15.307745
#
#         C17_C18  ...   G-U_X_G4677     EP_HH  Total_waste_gen  \
# 0    693.591932  ...   1046.579003     0.000     41847.992000
# ...

# %% [markdown]
# ## This is to be able to find the ANOVAs of the different A,  B, C columns. You will need to add all your other columns in

# %%
MeltedUKTotal1 = pd.melt(UK_Total_updated, id_vars = ['Year', 'Waste_types'], value_vars = ['A', 'B', 'C10_C12', 'C16'])

# %%
MeltedUKTotal1.head(50)
# Out:
#     Year                                        Waste_types variable  \
# 0   2010                                     Spent solvents        A
# 1   2010                    Acid, alkaline or saline wastes        A
# 2   2010                                          Used oils        A
# 3   2010                                    Chemical wastes        A
# 4   2010                        Industrial effluent sludges        A
# 5   2010       Sludges & liquid wastes from waste treatment        A
# 6   2010                    Health care & biological wastes        A
# 7   2010                           Metallic wastes, ferrous        A
# 8   2010                       Metallic wastes, non-ferrous        A
# 9   2010                             Metallic wastes, mixed        A
# 10  2010                                       Glass wastes        A
# 11  2010                           Paper & cardboard wastes        A
# 12  2010                                      Rubber wastes        A
# ...
